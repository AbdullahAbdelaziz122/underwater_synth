# %% [markdown]
# # Importing Liberaries

# %%
import torch
from torch.utils.data import Dataset
from torchvision import datasets
from torchvision.transforms import ToTensor
import matplotlib.pyplot as plt 
import pandas as pd
import glob
import os

# %% [markdown]
# # Datasets
#
# - ShipsEar
# - DS3500
# - Generated_Bellhop data
# - Ambiant Noise
# - Marine Life sounds

# %% [markdown]
# ## First Merging Data in one Dataset

# %% [markdown]
# ### Custom Dataset for submarine and Torpedo

# %% [markdown]
# # Problem Statement
